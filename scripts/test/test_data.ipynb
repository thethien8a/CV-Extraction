# %%
import psycopg2

# %%
connection = psycopg2.connect(
    host="localhost",
    port=5432,
    database="topcv",
    user="topcv",
    password="topcv_pass"
)

# %%
import pandas as pd
cursor = connection.cursor()
cursor.execute("SELECT * FROM cv_metadata")
rows = cursor.fetchall()
df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
connection.commit()

# %%
df.head()
# Out:
#       cv_id candidate_id          full_name            phone  \
# 0  47589520       324382        Lã Thảo Lâm  +84 34 751 8295
# 1  47559211      8495153  Nguyễn Trọng Bình     0972 063 736
# 2  47558383      4950955     Bùi Hoàng Phúc       0936057385
# 3  47550936      7617903   NGUYỄN PHÚC LINH   (+84)975133042
# 4  47542917      7017825       Chu Văn Mạnh       0984888188
#
#                         email campaign_id campaign_title   job_id  \
# 0         thaolamla@gmail.com     2350596  tuyển ctv DA  1965603
# 1           ntb3152@gmail.com     2350596  tuyển ctv DA  1965603
# 2   buiphuc02022002@gmail.com     2350596  tuyển ctv DA  1965603
# 3  nguyenphuclinh03@gmail.com     2350596  tuyển ctv DA  1965603
# 4      manhchu97348@gmail.com     2350596  tuyển ctv DA  1965603
#
#                   applied_position     application_date  ... apply_status  \
# 0  Cộng Tác Viên Phân Tích Dữ Liệu  2025-12-26 11:21:05  ...            0
# ...

# %%
df.shape
# Out:
# (224, 25)

# %%
cursor.close()
connection.close()
